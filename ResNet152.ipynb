# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile
filename="/content/drive/My Drive/HAM10000.zip"
# with ZipFile(filename,'r') as zip:
#   zip.extractall()
#   print("done")
# !unzip "/content/drive/My Drive/HAM10000.zip" -d '/content/HAM10000'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/HAM10000/ISIC_0029321.jpg
#   inflating: /content/HAM10000/ISIC_0029322.jpg
#   inflating: /content/HAM10000/ISIC_0029323.jpg
#   inflating: /content/HAM10000/ISIC_0029324.jpg
#   inflating: /content/HAM10000/ISIC_0029325.jpg
#   inflating: /content/HAM10000/ISIC_0029326.jpg
#   inflating: /content/HAM10000/ISIC_0029327.jpg
#   inflating: /content/HAM10000/ISIC_0029328.jpg
#   inflating: /content/HAM10000/ISIC_0029329.jpg
#   inflating: /content/HAM10000/ISIC_0029330.jpg
#   inflating: /content/HAM10000/ISIC_0029331.jpg
#   inflating: /content/HAM10000/ISIC_0029332.jpg
#   inflating: /content/HAM10000/ISIC_0029333.jpg
#   inflating: /content/HAM10000/ISIC_0029334.jpg
#   inflating: /content/HAM10000/ISIC_0029335.jpg
#   inflating: /content/HAM10000/ISIC_0029336.jpg
#   inflating: /content/HAM10000/ISIC_0029337.jpg
#   inflating: /content/HAM10000/ISIC_0029338.jpg
#   inflating: /content/HAM10000/ISIC_0029339.jpg
#   inflating: /content/HAM10000/ISIC_0029340.jpg
#   inflating: /content/HAM10000/ISIC_0029341.jpg
#   inflating: /content/HAM10000/ISIC_0029342.jpg
#   inflating: /content/HAM10000/ISIC_0029343.jpg
#   inflating: /content/HAM10000/ISIC_0029344.jpg
#   inflating: /content/HAM10000/ISIC_0029345.jpg
#   inflating: /content/HAM10000/ISIC_0029346.jpg
#   inflating: /content/HAM10000/ISIC_0029347.jpg
#   inflating: /content/HAM10000/ISIC_0029348.jpg
#   inflating: /content/HAM10000/ISIC_0029349.jpg
#   inflating: /content/HAM10000/ISIC_0029350.jpg
#   inflating: /content/HAM10000/ISIC_0029351.jpg
#   inflating: /content/HAM10000/ISIC_0029352.jpg
#   inflating: /content/HAM10000/ISIC_0029353.jpg
#   inflating: /content/HAM10000/ISIC_0029354.jpg
#   inflating: /content/HAM10000/ISIC_0029355.jpg
#   inflating: /content/HAM10000/ISIC_0029356.jpg
#   inflating: /content/HAM10000/ISIC_0029357.jpg
#   inflating: /content/HAM10000/ISIC_0029358.jpg
#   inflating: /content/HAM10000/ISIC_0029359.jpg
#   inflating: /content/HAM10000/ISIC_0029360.jpg
#   inflating: /content/HAM10000/ISIC_0029361.jpg
#   inflating: /content/HAM10000/ISIC_0029362.jpg
#   inflating: /content/HAM10000/ISIC_0029363.jpg
#   inflating: /content/HAM10000/ISIC_0029364.jpg
#   inflating: /content/HAM10000/ISIC_0029365.jpg
#   inflating: /content/HAM10000/ISIC_0029366.jpg
#   inflating: /content/HAM10000/ISIC_0029367.jpg
#   inflating: /content/HAM10000/ISIC_0029368.jpg
#   inflating: /content/HAM10000/ISIC_0029369.jpg
#   inflating: /content/HAM10000/ISIC_0029370.jpg
#   inflating: /content/HAM10000/ISIC_0029371.jpg
#   inflating: /content/HAM10000/ISIC_0029372.jpg
#   inflating: /content/HAM10000/ISIC_0029373.jpg
#   inflating: /content/HAM10000/ISIC_0029374.jpg
#   inflating: /content/HAM10000/ISIC_0029375.jpg
#   inflating: /content/HAM10000/ISIC_0029376.jpg
#   inflating: /content/HAM10000/ISIC_0029377.jpg
#   inflating: /content/HAM10000/ISIC_0029378.jpg
#   inflating: /content/HAM10000/ISIC_0029379.jpg
#   inflating: /content/HAM10000/ISIC_0029380.jpg
#   inflating: /content/HAM10000/ISIC_0029381.jpg
#   inflating: /content/HAM10000/ISIC_0029382.jpg
#   inflating: /content/HAM10000/ISIC_0029383.jpg
#   inflating: /content/HAM10000/ISIC_0029384.jpg
#   inflating: /content/HAM10000/ISIC_0029385.jpg
#   inflating: /content/HAM10000/ISIC_0029386.jpg
#   inflating: /content/HAM10000/ISIC_0029387.jpg
#   inflating: /content/HAM10000/ISIC_0029388.jpg
#   inflating: /content/HAM10000/ISIC_0029389.jpg
#   inflating: /content/HAM10000/ISIC_0029390.jpg
#   inflating: /content/HAM10000/ISIC_0029391.jpg
#   inflating: /content/HAM10000/ISIC_0029392.jpg
#   inflating: /content/HAM10000/ISIC_0029393.jpg
#   inflating: /content/HAM10000/ISIC_0029394.jpg
#   inflating: /content/HAM10000/ISIC_0029395.jpg
#   inflating: /content/HAM10000/ISIC_0029396.jpg
#   inflating: /content/HAM10000/ISIC_0029397.jpg
#   inflating: /content/HAM10000/ISIC_0029398.jpg
#   inflating: /content/HAM10000/ISIC_0029399.jpg
#   inflating: /content/HAM10000/ISIC_0029400.jpg
#   inflating: /content/HAM10000/ISIC_0029401.jpg
#   inflating: /content/HAM10000/ISIC_0029402.jpg
#   inflating: /content/HAM10000/ISIC_0029403.jpg
#   inflating: /content/HAM10000/ISIC_0029404.jpg
#   inflating: /content/HAM10000/ISIC_0029405.jpg
#   inflating: /content/HAM10000/ISIC_0029406.jpg
#   inflating: /content/HAM10000/ISIC_0029407.jpg
#   inflating: /content/HAM10000/ISIC_0029408.jpg
#   inflating: /content/HAM10000/ISIC_0029409.jpg
#   inflating: /content/HAM10000/ISIC_0029410.jpg
#   inflating: /content/HAM10000/ISIC_0029411.jpg
#   inflating: /content/HAM10000/ISIC_0029412.jpg
#   inflating: /content/HAM10000/ISIC_0029413.jpg
#   inflating: /content/HAM10000/ISIC_0029414.jpg
#   inflating: /content/HAM10000/ISIC_0029415.jpg
#   inflating: /content/HAM10000/ISIC_0029416.jpg
#   inflating: /content/HAM10000/ISIC_0029417.jpg
#   inflating: /content/HAM10000/ISIC_0029418.jpg
#   inflating: /content/HAM10000/ISIC_0029419.jpg
#   inflating: /content/HAM10000/ISIC_0029420.jpg
#   inflating: /content/HAM10000/ISIC_0029421.jpg
#   inflating: /content/HAM10000/ISIC_0029422.jpg
#   inflating: /content/HAM10000/ISIC_0029423.jpg
#   inflating: /content/HAM10000/ISIC_0029424.jpg
#   inflating: /content/HAM10000/ISIC_0029425.jpg
#   inflating: /content/HAM10000/ISIC_0029426.jpg
#   inflating: /content/HAM10000/ISIC_0029427.jpg
#   inflating: /content/HAM10000/ISIC_0029428.jpg
#   inflating: /content/HAM10000/ISIC_0029429.jpg
#   inflating: /content/HAM10000/ISIC_0029430.jpg
#   inflating: /content/HAM10000/ISIC_0029431.jpg
#   inflating: /content/HAM10000/ISIC_0029432.jpg
#   inflating: /content/HAM10000/ISIC_0029433.jpg
#   inflating: /content/HAM10000/ISIC_0029434.jpg
#   inflating: /content/HAM10000/ISIC_0029435.jpg
#   inflating: /content/HAM10000/ISIC_0029436.jpg
#   inflating: /content/HAM10000/ISIC_0029437.jpg
#   inflating: /content/HAM10000/ISIC_0029438.jpg
#   inflating: /content/HAM10000/ISIC_0029439.jpg
#   inflating: /content/HAM10000/ISIC_0029440.jpg
#   inflating: /content/HAM10000/ISIC_0029441.jpg
#   inflating: /content/HAM10000/ISIC_0029442.jpg
#   inflating: /content/HAM10000/ISIC_0029443.jpg
#   inflating: /content/HAM10000/ISIC_0029444.jpg
#   inflating: /content/HAM10000/ISIC_0029445.jpg
#   inflating: /content/HAM10000/ISIC_0029446.jpg
#   inflating: /content/HAM10000/ISIC_0029447.jpg
#   inflating: /content/HAM10000/ISIC_0029448.jpg
#   inflating: /content/HAM10000/ISIC_0029449.jpg
#   inflating: /content/HAM10000/ISIC_0029450.jpg
#   inflating: /content/HAM10000/ISIC_0029451.jpg
#   inflating: /content/HAM10000/ISIC_0029452.jpg
#   inflating: /content/HAM10000/ISIC_0029453.jpg
#   inflating: /content/HAM10000/ISIC_0029454.jpg
#   inflating: /content/HAM10000/ISIC_0029455.jpg
#   inflating: /content/HAM10000/ISIC_0029456.jpg
#   inflating: /content/HAM10000/ISIC_0029457.jpg
#   inflating: /content/HAM10000/ISIC_0029458.jpg
#   inflating: /content/HAM10000/ISIC_0029459.jpg
#   inflating: /content/HAM10000/ISIC_0029460.jpg
#   inflating: /content/HAM10000/ISIC_0029461.jpg
#   inflating: /content/HAM10000/ISIC_0029462.jpg
#   inflating: /content/HAM10000/ISIC_0029463.jpg
#   inflating: /content/HAM10000/ISIC_0029464.jpg
#   inflating: /content/HAM10000/ISIC_0029465.jpg
#   inflating: /content/HAM10000/ISIC_0029466.jpg
#   inflating: /content/HAM10000/ISIC_0029467.jpg
#   inflating: /content/HAM10000/ISIC_0029468.jpg
#   inflating: /content/HAM10000/ISIC_0029469.jpg
#   inflating: /content/HAM10000/ISIC_0029470.jpg
#   inflating: /content/HAM10000/ISIC_0029471.jpg
#   inflating: /content/HAM10000/ISIC_0029472.jpg
#   inflating: /content/HAM10000/ISIC_0029473.jpg
#   inflating: /content/HAM10000/ISIC_0029474.jpg
#   inflating: /content/HAM10000/ISIC_0029475.jpg
#   inflating: /content/HAM10000/ISIC_0029476.jpg
#   inflating: /content/HAM10000/ISIC_0029477.jpg
#   inflating: /content/HAM10000/ISIC_0029478.jpg
#   inflating: /content/HAM10000/ISIC_0029479.jpg
#   inflating: /content/HAM10000/ISIC_0029480.jpg
#   inflating: /content/HAM10000/ISIC_0029481.jpg
#   inflating: /content/HAM10000/ISIC_0029482.jpg
#   inflating: /content/HAM10000/ISIC_0029483.jpg
#   inflating: /content/HAM10000/ISIC_0029484.jpg
#   inflating: /content/HAM10000/ISIC_0029485.jpg
#   inflating: /content/HAM10000/ISIC_0029486.jpg
#   inflating: /content/HAM10000/ISIC_0029487.jpg
#   inflating: /content/HAM10000/ISIC_0029488.jpg
#   inflating: /content/HAM10000/ISIC_0029489.jpg
#   inflating: /content/HAM10000/ISIC_0029490.jpg
#   inflating: /content/HAM10000/ISIC_0029491.jpg
#   inflating: /content/HAM10000/ISIC_0029492.jpg
#   inflating: /content/HAM10000/ISIC_0029493.jpg
#   inflating: /content/HAM10000/ISIC_0029494.jpg
#   inflating: /content/HAM10000/ISIC_0029495.jpg
#   inflating: /content/HAM10000/ISIC_0029496.jpg
#   inflating: /content/HAM10000/ISIC_0029497.jpg
#   inflating: /content/HAM10000/ISIC_0029498.jpg
#   inflating: /content/HAM10000/ISIC_0029499.jpg
#   inflating: /content/HAM10000/ISIC_0029500.jpg
#   inflating: /content/HAM10000/ISIC_0029501.jpg
#   inflating: /content/HAM10000/ISIC_0029502.jpg
#   inflating: /content/HAM10000/ISIC_0029503.jpg
#   inflating: /content/HAM10000/ISIC_0029504.jpg
#   inflating: /content/HAM10000/ISIC_0029505.jpg
#   inflating: /content/HAM10000/ISIC_0029506.jpg
#   inflating: /content/HAM10000/ISIC_0029507.jpg
#   inflating: /content/HAM10000/ISIC_0029508.jpg
#   inflating: /content/HAM10000/ISIC_0029509.jpg
#   inflating: /content/HAM10000/ISIC_0029510.jpg
#   inflating: /content/HAM10000/ISIC_0029511.jpg
#   inflating: /content/HAM10000/ISIC_0029512.jpg
#   inflating: /content/HAM10000/ISIC_0029513.jpg
#   inflating: /content/HAM10000/ISIC_0029514.jpg
#   inflating: /content/HAM10000/ISIC_0029515.jpg
#   inflating: /content/HAM10000/ISIC_0029516.jpg
#   inflating: /content/HAM10000/ISIC_0029517.jpg
#   inflating: /content/HAM10000/ISIC_0029518.jpg
#   inflating: /content/HAM10000/ISIC_0029519.jpg
#   inflating: /content/HAM10000/ISIC_0029520.jpg
#   inflating: /content/HAM10000/ISIC_0029521.jpg
#   inflating: /content/HAM10000/ISIC_0029522.jpg
#   inflating: /content/HAM10000/ISIC_0029523.jpg
#   inflating: /content/HAM10000/ISIC_0029524.jpg
#   inflating: /content/HAM10000/ISIC_0029525.jpg
#   inflating: /content/HAM10000/ISIC_0029526.jpg
#   inflating: /content/HAM10000/ISIC_0029527.jpg
#   inflating: /content/HAM10000/ISIC_0029528.jpg
#   inflating: /content/HAM10000/ISIC_0029529.jpg
#   inflating: /content/HAM10000/ISIC_0029530.jpg
#   inflating: /content/HAM10000/ISIC_0029531.jpg
#   inflating: /content/HAM10000/ISIC_0029532.jpg
#   inflating: /content/HAM10000/ISIC_0029533.jpg
#   inflating: /content/HAM10000/ISIC_0029534.jpg
#   inflating: /content/HAM10000/ISIC_0029535.jpg
#   inflating: /content/HAM10000/ISIC_0029536.jpg
#   inflating: /content/HAM10000/ISIC_0029537.jpg
#   inflating: /content/HAM10000/ISIC_0029538.jpg
#   inflating: /content/HAM10000/ISIC_0029539.jpg
#   inflating: /content/HAM10000/ISIC_0029540.jpg
#   inflating: /content/HAM10000/ISIC_0029541.jpg
#   inflating: /content/HAM10000/ISIC_0029542.jpg
#   inflating: /content/HAM10000/ISIC_0029543.jpg
#   inflating: /content/HAM10000/ISIC_0029544.jpg
#   inflating: /content/HAM10000/ISIC_0029545.jpg
#   inflating: /content/HAM10000/ISIC_0029546.jpg
#   inflating: /content/HAM10000/ISIC_0029547.jpg
#   inflating: /content/HAM10000/ISIC_0029548.jpg
#   inflating: /content/HAM10000/ISIC_0029549.jpg
#   inflating: /content/HAM10000/ISIC_0029550.jpg
#   inflating: /content/HAM10000/ISIC_0029551.jpg
#   inflating: /content/HAM10000/ISIC_0029552.jpg
#   inflating: /content/HAM10000/ISIC_0029553.jpg
#   inflating: /content/HAM10000/ISIC_0029554.jpg
#   inflating: /content/HAM10000/ISIC_0029555.jpg
#   inflating: /content/HAM10000/ISIC_0029556.jpg
#   inflating: /content/HAM10000/ISIC_0029557.jpg
#   inflating: /content/HAM10000/ISIC_0029558.jpg
#   inflating: /content/HAM10000/ISIC_0029559.jpg
#   inflating: /content/HAM10000/ISIC_0029560.jpg
#   inflating: /content/HAM10000/ISIC_0029561.jpg
#   inflating: /content/HAM10000/ISIC_0029562.jpg
#   inflating: /content/HAM10000/ISIC_0029563.jpg
#   inflating: /content/HAM10000/ISIC_0029564.jpg
#   inflating: /content/HAM10000/ISIC_0029565.jpg
#   inflating: /content/HAM10000/ISIC_0029566.jpg
#   inflating: /content/HAM10000/ISIC_0029567.jpg
#   inflating: /content/HAM10000/ISIC_0029568.jpg
#   inflating: /content/HAM10000/ISIC_0029569.jpg
#   inflating: /content/HAM10000/ISIC_0029570.jpg
#   inflating: /content/HAM10000/ISIC_0029571.jpg
#   inflating: /content/HAM10000/ISIC_0029572.jpg
#   inflating: /content/HAM10000/ISIC_0029573.jpg
#   inflating: /content/HAM10000/ISIC_0029574.jpg
#   inflating: /content/HAM10000/ISIC_0029575.jpg
#   inflating: /content/HAM10000/ISIC_0029576.jpg
#   inflating: /content/HAM10000/ISIC_0029577.jpg
#   inflating: /content/HAM10000/ISIC_0029578.jpg
#   inflating: /content/HAM10000/ISIC_0029579.jpg
#   inflating: /content/HAM10000/ISIC_0029580.jpg
#   inflating: /content/HAM10000/ISIC_0029581.jpg
#   inflating: /content/HAM10000/ISIC_0029582.jpg
#   inflating: /content/HAM10000/ISIC_0029583.jpg
#   inflating: /content/HAM10000/ISIC_0029584.jpg
#   inflating: /content/HAM10000/ISIC_0029585.jpg
#   inflating: /content/HAM10000/ISIC_0029586.jpg
#   inflating: /content/HAM10000/ISIC_0029587.jpg
#   inflating: /content/HAM10000/ISIC_0029588.jpg
#   inflating: /content/HAM10000/ISIC_0029589.jpg
#   inflating: /content/HAM10000/ISIC_0029590.jpg
#   inflating: /content/HAM10000/ISIC_0029591.jpg
#   inflating: /content/HAM10000/ISIC_0029592.jpg
#   inflating: /content/HAM10000/ISIC_0029593.jpg
#   inflating: /content/HAM10000/ISIC_0029594.jpg
#   inflating: /content/HAM10000/ISIC_0029595.jpg
#   inflating: /content/HAM10000/ISIC_0029596.jpg
#   inflating: /content/HAM10000/ISIC_0029597.jpg
#   inflating: /content/HAM10000/ISIC_0029598.jpg
#   inflating: /content/HAM10000/ISIC_0029599.jpg
#   inflating: /content/HAM10000/ISIC_0029600.jpg
#   inflating: /content/HAM10000/ISIC_0029601.jpg
#   inflating: /content/HAM10000/ISIC_0029602.jpg
#   inflating: /content/HAM10000/ISIC_0029603.jpg
#   inflating: /content/HAM10000/ISIC_0029604.jpg
#   inflating: /content/HAM10000/ISIC_0029605.jpg
#   inflating: /content/HAM10000/ISIC_0029606.jpg
#   inflating: /content/HAM10000/ISIC_0029607.jpg
#   inflating: /content/HAM10000/ISIC_0029608.jpg
#   inflating: /content/HAM10000/ISIC_0029609.jpg
#   inflating: /content/HAM10000/ISIC_0029610.jpg
#   inflating: /content/HAM10000/ISIC_0029611.jpg
#   inflating: /content/HAM10000/ISIC_0029612.jpg
#   inflating: /content/HAM10000/ISIC_0029613.jpg
#   inflating: /content/HAM10000/ISIC_0029614.jpg
#   inflating: /content/HAM10000/ISIC_0029615.jpg
#   inflating: /content/HAM10000/ISIC_0029616.jpg
#   inflating: /content/HAM10000/ISIC_0029617.jpg
#   inflating: /content/HAM10000/ISIC_0029618.jpg
#   inflating: /content/HAM10000/ISIC_0029619.jpg
#   inflating: /content/HAM10000/ISIC_0029620.jpg
#   inflating: /content/HAM10000/ISIC_0029621.jpg
#   inflating: /content/HAM10000/ISIC_0029622.jpg
#   inflating: /content/HAM10000/ISIC_0029623.jpg
#   inflating: /content/HAM10000/ISIC_0029624.jpg
#   inflating: /content/HAM10000/ISIC_0029625.jpg
#   inflating: /content/HAM10000/ISIC_0029626.jpg
#   inflating: /content/HAM10000/ISIC_0029627.jpg
#   inflating: /content/HAM10000/ISIC_0029628.jpg
#   inflating: /content/HAM10000/ISIC_0029629.jpg
#   inflating: /content/HAM10000/ISIC_0029630.jpg
#   inflating: /content/HAM10000/ISIC_0029631.jpg
#   inflating: /content/HAM10000/ISIC_0029632.jpg
#   inflating: /content/HAM10000/ISIC_0029633.jpg
#   inflating: /content/HAM10000/ISIC_0029634.jpg
#   inflating: /content/HAM10000/ISIC_0029635.jpg
#   inflating: /content/HAM10000/ISIC_0029636.jpg
#   inflating: /content/HAM10000/ISIC_0029637.jpg
#   inflating: /content/HAM10000/ISIC_0029638.jpg
#   inflating: /content/HAM10000/ISIC_0029639.jpg
#   inflating: /content/HAM10000/ISIC_0029640.jpg
#   inflating: /content/HAM10000/ISIC_0029641.jpg
#   inflating: /content/HAM10000/ISIC_0029642.jpg
#   inflating: /content/HAM10000/ISIC_0029643.jpg
#   inflating: /content/HAM10000/ISIC_0029644.jpg
#   inflating: /content/HAM10000/ISIC_0029645.jpg
#   inflating: /content/HAM10000/ISIC_0029646.jpg
#   inflating: /content/HAM10000/ISIC_0029647.jpg
#   inflating: /content/HAM10000/ISIC_0029648.jpg
#   inflating: /content/HAM10000/ISIC_0029649.jpg
#   inflating: /content/HAM10000/ISIC_0029650.jpg
#   inflating: /content/HAM10000/ISIC_0029651.jpg
#   inflating: /content/HAM10000/ISIC_0029652.jpg
#   inflating: /content/HAM10000/ISIC_0029653.jpg
#   inflating: /content/HAM10000/ISIC_0029654.jpg
#   inflating: /content/HAM10000/ISIC_0029655.jpg
#   inflating: /content/HAM10000/ISIC_0029656.jpg
#   inflating: /content/HAM10000/ISIC_0029657.jpg
#   inflating: /content/HAM10000/ISIC_0029658.jpg
#   inflating: /content/HAM10000/ISIC_0029659.jpg
#   inflating: /content/HAM10000/ISIC_0029660.jpg
#   inflating: /content/HAM10000/ISIC_0029661.jpg
#   inflating: /content/HAM10000/ISIC_0029662.jpg
#   inflating: /content/HAM10000/ISIC_0029663.jpg
#   inflating: /content/HAM10000/ISIC_0029664.jpg
#   inflating: /content/HAM10000/ISIC_0029665.jpg
#   inflating: /content/HAM10000/ISIC_0029666.jpg
#   inflating: /content/HAM10000/ISIC_0029667.jpg
#   inflating: /content/HAM10000/ISIC_0029668.jpg
#   inflating: /content/HAM10000/ISIC_0029669.jpg
#   inflating: /content/HAM10000/ISIC_0029670.jpg
#   inflating: /content/HAM10000/ISIC_0029671.jpg
#   inflating: /content/HAM10000/ISIC_0029672.jpg
#   inflating: /content/HAM10000/ISIC_0029673.jpg
#   inflating: /content/HAM10000/ISIC_0029674.jpg
#   inflating: /content/HAM10000/ISIC_0029675.jpg
#   inflating: /content/HAM10000/ISIC_0029676.jpg
#   inflating: /content/HAM10000/ISIC_0029677.jpg
#   inflating: /content/HAM10000/ISIC_0029678.jpg
#   inflating: /content/HAM10000/ISIC_0029679.jpg
#   inflating: /content/HAM10000/ISIC_0029680.jpg
#   inflating: /content/HAM10000/ISIC_0029681.jpg
#   inflating: /content/HAM10000/ISIC_0029682.jpg
#   inflating: /content/HAM10000/ISIC_0029683.jpg
#   inflating: /content/HAM10000/ISIC_0029684.jpg
#   inflating: /content/HAM10000/ISIC_0029685.jpg
#   inflating: /content/HAM10000/ISIC_0029686.jpg
#   inflating: /content/HAM10000/ISIC_0029687.jpg
#   inflating: /content/HAM10000/ISIC_0029688.jpg
#   inflating: /content/HAM10000/ISIC_0029689.jpg
#   inflating: /content/HAM10000/ISIC_0029690.jpg
#   inflating: /content/HAM10000/ISIC_0029691.jpg
#   inflating: /content/HAM10000/ISIC_0029692.jpg
#   inflating: /content/HAM10000/ISIC_0029693.jpg
#   inflating: /content/HAM10000/ISIC_0029694.jpg
#   inflating: /content/HAM10000/ISIC_0029695.jpg
#   inflating: /content/HAM10000/ISIC_0029696.jpg
#   inflating: /content/HAM10000/ISIC_0029697.jpg
#   inflating: /content/HAM10000/ISIC_0029698.jpg
#   inflating: /content/HAM10000/ISIC_0029699.jpg
#   inflating: /content/HAM10000/ISIC_0029700.jpg
#   inflating: /content/HAM10000/ISIC_0029701.jpg
#   inflating: /content/HAM10000/ISIC_0029702.jpg
#   inflating: /content/HAM10000/ISIC_0029703.jpg
#   inflating: /content/HAM10000/ISIC_0029704.jpg
#   inflating: /content/HAM10000/ISIC_0029705.jpg
#   inflating: /content/HAM10000/ISIC_0029706.jpg
#   inflating: /content/HAM10000/ISIC_0029707.jpg
#   inflating: /content/HAM10000/ISIC_0029708.jpg
#   inflating: /content/HAM10000/ISIC_0029709.jpg
#   inflating: /content/HAM10000/ISIC_0029710.jpg
#   inflating: /content/HAM10000/ISIC_0029711.jpg
#   inflating: /content/HAM10000/ISIC_0029712.jpg
#   inflating: /content/HAM10000/ISIC_0029713.jpg
#   inflating: /content/HAM10000/ISIC_0029714.jpg
#   inflating: /content/HAM10000/ISIC_0029715.jpg
#   inflating: /content/HAM10000/ISIC_0029716.jpg
#   inflating: /content/HAM10000/ISIC_0029717.jpg
#   inflating: /content/HAM10000/ISIC_0029718.jpg
#   inflating: /content/HAM10000/ISIC_0029719.jpg
#   inflating: /content/HAM10000/ISIC_0029720.jpg
#   inflating: /content/HAM10000/ISIC_0029721.jpg
#   inflating: /content/HAM10000/ISIC_0029722.jpg
#   inflating: /content/HAM10000/ISIC_0029723.jpg
#   inflating: /content/HAM10000/ISIC_0029724.jpg
#   inflating: /content/HAM10000/ISIC_0029725.jpg
#   inflating: /content/HAM10000/ISIC_0029726.jpg
#   inflating: /content/HAM10000/ISIC_0029727.jpg
#   inflating: /content/HAM10000/ISIC_0029728.jpg
#   inflating: /content/HAM10000/ISIC_0029729.jpg
#   inflating: /content/HAM10000/ISIC_0029730.jpg
#   inflating: /content/HAM10000/ISIC_0029731.jpg
#   inflating: /content/HAM10000/ISIC_0029732.jpg
#   inflating: /content/HAM10000/ISIC_0029733.jpg
#   inflating: /content/HAM10000/ISIC_0029734.jpg
#   inflating: /content/HAM10000/ISIC_0029735.jpg
#   inflating: /content/HAM10000/ISIC_0029736.jpg
#   inflating: /content/HAM10000/ISIC_0029737.jpg
#   inflating: /content/HAM10000/ISIC_0029738.jpg
#   inflating: /content/HAM10000/ISIC_0029739.jpg
#   inflating: /content/HAM10000/ISIC_0029740.jpg
#   inflating: /content/HAM10000/ISIC_0029741.jpg
#   inflating: /content/HAM10000/ISIC_0029742.jpg
#   inflating: /content/HAM10000/ISIC_0029743.jpg
#   inflating: /content/HAM10000/ISIC_0029744.jpg
#   inflating: /content/HAM10000/ISIC_0029745.jpg
#   inflating: /content/HAM10000/ISIC_0029746.jpg
#   inflating: /content/HAM10000/ISIC_0029747.jpg
#   inflating: /content/HAM10000/ISIC_0029748.jpg
#   inflating: /content/HAM10000/ISIC_0029749.jpg
#   inflating: /content/HAM10000/ISIC_0029750.jpg
#   inflating: /content/HAM10000/ISIC_0029751.jpg
#   inflating: /content/HAM10000/ISIC_0029752.jpg
#   inflating: /content/HAM10000/ISIC_0029753.jpg
#   inflating: /content/HAM10000/ISIC_0029754.jpg
#   inflating: /content/HAM10000/ISIC_0029755.jpg
#   inflating: /content/HAM10000/ISIC_0029756.jpg
#   inflating: /content/HAM10000/ISIC_0029757.jpg
#   inflating: /content/HAM10000/ISIC_0029758.jpg
#   inflating: /content/HAM10000/ISIC_0029759.jpg
#   inflating: /content/HAM10000/ISIC_0029760.jpg
#   inflating: /content/HAM10000/ISIC_0029761.jpg
#   inflating: /content/HAM10000/ISIC_0029762.jpg
#   inflating: /content/HAM10000/ISIC_0029763.jpg
#   inflating: /content/HAM10000/ISIC_0029764.jpg
#   inflating: /content/HAM10000/ISIC_0029765.jpg
#   inflating: /content/HAM10000/ISIC_0029766.jpg
#   inflating: /content/HAM10000/ISIC_0029767.jpg
#   inflating: /content/HAM10000/ISIC_0029768.jpg
#   inflating: /content/HAM10000/ISIC_0029769.jpg
#   inflating: /content/HAM10000/ISIC_0029770.jpg
#   inflating: /content/HAM10000/ISIC_0029771.jpg
#   inflating: /content/HAM10000/ISIC_0029772.jpg
#   inflating: /content/HAM10000/ISIC_0029773.jpg
#   inflating: /content/HAM10000/ISIC_0029774.jpg
#   inflating: /content/HAM10000/ISIC_0029775.jpg
#   inflating: /content/HAM10000/ISIC_0029776.jpg
#   inflating: /content/HAM10000/ISIC_0029777.jpg
#   inflating: /content/HAM10000/ISIC_0029778.jpg
#   inflating: /content/HAM10000/ISIC_0029779.jpg
#   inflating: /content/HAM10000/ISIC_0029780.jpg
#   inflating: /content/HAM10000/ISIC_0029781.jpg
#   inflating: /content/HAM10000/ISIC_0029782.jpg
#   inflating: /content/HAM10000/ISIC_0029783.jpg
#   inflating: /content/HAM10000/ISIC_0029784.jpg
#   inflating: /content/HAM10000/ISIC_0029785.jpg
#   inflating: /content/HAM10000/ISIC_0029786.jpg
#   inflating: /content/HAM10000/ISIC_0029787.jpg
#   inflating: /content/HAM10000/ISIC_0029788.jpg
#   inflating: /content/HAM10000/ISIC_0029789.jpg
#   inflating: /content/HAM10000/ISIC_0029790.jpg
#   inflating: /content/HAM10000/ISIC_0029791.jpg
#   inflating: /content/HAM10000/ISIC_0029792.jpg
#   inflating: /content/HAM10000/ISIC_0029793.jpg
#   inflating: /content/HAM10000/ISIC_0029794.jpg
#   inflating: /content/HAM10000/ISIC_0029795.jpg
#   inflating: /content/HAM10000/ISIC_0029796.jpg
#   inflating: /content/HAM10000/ISIC_0029797.jpg
#   inflating: /content/HAM10000/ISIC_0029798.jpg
#   inflating: /content/HAM10000/ISIC_0029799.jpg
#   inflating: /content/HAM10000/ISIC_0029800.jpg
#   inflating: /content/HAM10000/ISIC_0029801.jpg
#   inflating: /content/HAM10000/ISIC_0029802.jpg
#   inflating: /content/HAM10000/ISIC_0029803.jpg
#   inflating: /content/HAM10000/ISIC_0029804.jpg
#   inflating: /content/HAM10000/ISIC_0029805.jpg
#   inflating: /content/HAM10000/ISIC_0029806.jpg
#   inflating: /content/HAM10000/ISIC_0029807.jpg
#   inflating: /content/HAM10000/ISIC_0029808.jpg
#   inflating: /content/HAM10000/ISIC_0029809.jpg
#   inflating: /content/HAM10000/ISIC_0029810.jpg
#   inflating: /content/HAM10000/ISIC_0029811.jpg
#   inflating: /content/HAM10000/ISIC_0029812.jpg
#   inflating: /content/HAM10000/ISIC_0029813.jpg
#   inflating: /content/HAM10000/ISIC_0029814.jpg
#   inflating: /content/HAM10000/ISIC_0029815.jpg
#   inflating: /content/HAM10000/ISIC_0029816.jpg
#   inflating: /content/HAM10000/ISIC_0029817.jpg
#   inflating: /content/HAM10000/ISIC_0029818.jpg
#   inflating: /content/HAM10000/ISIC_0029819.jpg
#   inflating: /content/HAM10000/ISIC_0029820.jpg
#   inflating: /content/HAM10000/ISIC_0029821.jpg
#   inflating: /content/HAM10000/ISIC_0029822.jpg
#   inflating: /content/HAM10000/ISIC_0029823.jpg
#   inflating: /content/HAM10000/ISIC_0029824.jpg
#   inflating: /content/HAM10000/ISIC_0029825.jpg
#   inflating: /content/HAM10000/ISIC_0029826.jpg
#   inflating: /content/HAM10000/ISIC_0029827.jpg
#   inflating: /content/HAM10000/ISIC_0029828.jpg
#   inflating: /content/HAM10000/ISIC_0029829.jpg
#   inflating: /content/HAM10000/ISIC_0029830.jpg
#   inflating: /content/HAM10000/ISIC_0029831.jpg
#   inflating: /content/HAM10000/ISIC_0029832.jpg
#   inflating: /content/HAM10000/ISIC_0029833.jpg
#   inflating: /content/HAM10000/ISIC_0029834.jpg
#   inflating: /content/HAM10000/ISIC_0029835.jpg
#   inflating: /content/HAM10000/ISIC_0029836.jpg
#   inflating: /content/HAM10000/ISIC_0029837.jpg
#   inflating: /content/HAM10000/ISIC_0029838.jpg
#   inflating: /content/HAM10000/ISIC_0029839.jpg
#   inflating: /content/HAM10000/ISIC_0029840.jpg
#   inflating: /content/HAM10000/ISIC_0029841.jpg
#   inflating: /content/HAM10000/ISIC_0029842.jpg
#   inflating: /content/HAM10000/ISIC_0029843.jpg
#   inflating: /content/HAM10000/ISIC_0029844.jpg
#   inflating: /content/HAM10000/ISIC_0029845.jpg
#   inflating: /content/HAM10000/ISIC_0029846.jpg
#   inflating: /content/HAM10000/ISIC_0029847.jpg
#   inflating: /content/HAM10000/ISIC_0029848.jpg
#   inflating: /content/HAM10000/ISIC_0029849.jpg
#   inflating: /content/HAM10000/ISIC_0029850.jpg
#   inflating: /content/HAM10000/ISIC_0029851.jpg
#   inflating: /content/HAM10000/ISIC_0029852.jpg
#   inflating: /content/HAM10000/ISIC_0029853.jpg
#   inflating: /content/HAM10000/ISIC_0029854.jpg
#   inflating: /content/HAM10000/ISIC_0029855.jpg
#   inflating: /content/HAM10000/ISIC_0029856.jpg
#   inflating: /content/HAM10000/ISIC_0029857.jpg
#   inflating: /content/HAM10000/ISIC_0029858.jpg
#   inflating: /content/HAM10000/ISIC_0029859.jpg
#   inflating: /content/HAM10000/ISIC_0029860.jpg
#   inflating: /content/HAM10000/ISIC_0029861.jpg
#   inflating: /content/HAM10000/ISIC_0029862.jpg
#   inflating: /content/HAM10000/ISIC_0029863.jpg
#   inflating: /content/HAM10000/ISIC_0029864.jpg
#   inflating: /content/HAM10000/ISIC_0029865.jpg
#   inflating: /content/HAM10000/ISIC_0029866.jpg
#   inflating: /content/HAM10000/ISIC_0029867.jpg
#   inflating: /content/HAM10000/ISIC_0029868.jpg
#   inflating: /content/HAM10000/ISIC_0029869.jpg
#   inflating: /content/HAM10000/ISIC_0029870.jpg
#   inflating: /content/HAM10000/ISIC_0029871.jpg
#   inflating: /content/HAM10000/ISIC_0029872.jpg
#   inflating: /content/HAM10000/ISIC_0029873.jpg
#   inflating: /content/HAM10000/ISIC_0029874.jpg
#   inflating: /content/HAM10000/ISIC_0029875.jpg
#   inflating: /content/HAM10000/ISIC_0029876.jpg
#   inflating: /content/HAM10000/ISIC_0029877.jpg
#   inflating: /content/HAM10000/ISIC_0029878.jpg
#   inflating: /content/HAM10000/ISIC_0029879.jpg
#   inflating: /content/HAM10000/ISIC_0029880.jpg
#   inflating: /content/HAM10000/ISIC_0029881.jpg
#   inflating: /content/HAM10000/ISIC_0029882.jpg
#   inflating: /content/HAM10000/ISIC_0029883.jpg
#   inflating: /content/HAM10000/ISIC_0029884.jpg
#   inflating: /content/HAM10000/ISIC_0029885.jpg
#   inflating: /content/HAM10000/ISIC_0029886.jpg
#   inflating: /content/HAM10000/ISIC_0029887.jpg
#   inflating: /content/HAM10000/ISIC_0029888.jpg
#   inflating: /content/HAM10000/ISIC_0029889.jpg
#   inflating: /content/HAM10000/ISIC_0029890.jpg
#   inflating: /content/HAM10000/ISIC_0029891.jpg
#   inflating: /content/HAM10000/ISIC_0029892.jpg
#   inflating: /content/HAM10000/ISIC_0029893.jpg
#   inflating: /content/HAM10000/ISIC_0029894.jpg
#   inflating: /content/HAM10000/ISIC_0029895.jpg
#   inflating: /content/HAM10000/ISIC_0029896.jpg
#   inflating: /content/HAM10000/ISIC_0029897.jpg
#   inflating: /content/HAM10000/ISIC_0029898.jpg
#   inflating: /content/HAM10000/ISIC_0029899.jpg
#   inflating: /content/HAM10000/ISIC_0029900.jpg
#   inflating: /content/HAM10000/ISIC_0029901.jpg
#   inflating: /content/HAM10000/ISIC_0029902.jpg
#   inflating: /content/HAM10000/ISIC_0029903.jpg
#   inflating: /content/HAM10000/ISIC_0029904.jpg
#   inflating: /content/HAM10000/ISIC_0029905.jpg
#   inflating: /content/HAM10000/ISIC_0029906.jpg
#   inflating: /content/HAM10000/ISIC_0029907.jpg
#   inflating: /content/HAM10000/ISIC_0029908.jpg
#   inflating: /content/HAM10000/ISIC_0029909.jpg
#   inflating: /content/HAM10000/ISIC_0029910.jpg
#   inflating: /content/HAM10000/ISIC_0029911.jpg
#   inflating: /content/HAM10000/ISIC_0029912.jpg
#   inflating: /content/HAM10000/ISIC_0029913.jpg
#   inflating: /content/HAM10000/ISIC_0029914.jpg
#   inflating: /content/HAM10000/ISIC_0029915.jpg
#   inflating: /content/HAM10000/ISIC_0029916.jpg
#   inflating: /content/HAM10000/ISIC_0029917.jpg
#   inflating: /content/HAM10000/ISIC_0029918.jpg
#   inflating: /content/HAM10000/ISIC_0029919.jpg
#   inflating: /content/HAM10000/ISIC_0029920.jpg
#   inflating: /content/HAM10000/ISIC_0029921.jpg
#   inflating: /content/HAM10000/ISIC_0029922.jpg
#   inflating: /content/HAM10000/ISIC_0029923.jpg
#   inflating: /content/HAM10000/ISIC_0029924.jpg
#   inflating: /content/HAM10000/ISIC_0029925.jpg
#   inflating: /content/HAM10000/ISIC_0029926.jpg
#   inflating: /content/HAM10000/ISIC_0029927.jpg
#   inflating: /content/HAM10000/ISIC_0029928.jpg
#   inflating: /content/HAM10000/ISIC_0029929.jpg
#   inflating: /content/HAM10000/ISIC_0029930.jpg
#   inflating: /content/HAM10000/ISIC_0029931.jpg
#   inflating: /content/HAM10000/ISIC_0029932.jpg
#   inflating: /content/HAM10000/ISIC_0029933.jpg
#   inflating: /content/HAM10000/ISIC_0029934.jpg
#   inflating: /content/HAM10000/ISIC_0029935.jpg
#   inflating: /content/HAM10000/ISIC_0029936.jpg
#   inflating: /content/HAM10000/ISIC_0029937.jpg
#   inflating: /content/HAM10000/ISIC_0029938.jpg
#   inflating: /content/HAM10000/ISIC_0029939.jpg
#   inflating: /content/HAM10000/ISIC_0029940.jpg
#   inflating: /content/HAM10000/ISIC_0029941.jpg
#   inflating: /content/HAM10000/ISIC_0029942.jpg
#   inflating: /content/HAM10000/ISIC_0029943.jpg
#   inflating: /content/HAM10000/ISIC_0029944.jpg
#   inflating: /content/HAM10000/ISIC_0029945.jpg
#   inflating: /content/HAM10000/ISIC_0029946.jpg
#   inflating: /content/HAM10000/ISIC_0029947.jpg
#   inflating: /content/HAM10000/ISIC_0029948.jpg
#   inflating: /content/HAM10000/ISIC_0029949.jpg
#   inflating: /content/HAM10000/ISIC_0029950.jpg
#   inflating: /content/HAM10000/ISIC_0029951.jpg
#   inflating: /content/HAM10000/ISIC_0029952.jpg
#   inflating: /content/HAM10000/ISIC_0029953.jpg
#   inflating: /content/HAM10000/ISIC_0029954.jpg
#   inflating: /content/HAM10000/ISIC_0029955.jpg
#   inflating: /content/HAM10000/ISIC_0029956.jpg
#   inflating: /content/HAM10000/ISIC_0029957.jpg
#   inflating: /content/HAM10000/ISIC_0029958.jpg
#   inflating: /content/HAM10000/ISIC_0029959.jpg
#   inflating: /content/HAM10000/ISIC_0029960.jpg
#   inflating: /content/HAM10000/ISIC_0029961.jpg
#   inflating: /content/HAM10000/ISIC_0029962.jpg
#   inflating: /content/HAM10000/ISIC_0029963.jpg
#   inflating: /content/HAM10000/ISIC_0029964.jpg
#   inflating: /content/HAM10000/ISIC_0029965.jpg
#   inflating: /content/HAM10000/ISIC_0029966.jpg
#   inflating: /content/HAM10000/ISIC_0029967.jpg
#   inflating: /content/HAM10000/ISIC_0029968.jpg
#   inflating: /content/HAM10000/ISIC_0029969.jpg
#   inflating: /content/HAM10000/ISIC_0029970.jpg
#   inflating: /content/HAM10000/ISIC_0029971.jpg
#   inflating: /content/HAM10000/ISIC_0029972.jpg
#   inflating: /content/HAM10000/ISIC_0029973.jpg
#   inflating: /content/HAM10000/ISIC_0029974.jpg
#   inflating: /content/HAM10000/ISIC_0029975.jpg
#   inflating: /content/HAM10000/ISIC_0029976.jpg
#   inflating: /content/HAM10000/ISIC_0029977.jpg
#   inflating: /content/HAM10000/ISIC_0029978.jpg
#   inflating: /content/HAM10000/ISIC_0029979.jpg
#   inflating: /content/HAM10000/ISIC_0029980.jpg
#   inflating: /content/HAM10000/ISIC_0029981.jpg
#   inflating: /content/HAM10000/ISIC_0029982.jpg
#   inflating: /content/HAM10000/ISIC_0029983.jpg
#   inflating: /content/HAM10000/ISIC_0029984.jpg
#   inflating: /content/HAM10000/ISIC_0029985.jpg
#   inflating: /content/HAM10000/ISIC_0029986.jpg
#   inflating: /content/HAM10000/ISIC_0029987.jpg
#   inflating: /content/HAM10000/ISIC_0029988.jpg
#   inflating: /content/HAM10000/ISIC_0029989.jpg
#   inflating: /content/HAM10000/ISIC_0029990.jpg
#   inflating: /content/HAM10000/ISIC_0029991.jpg
#   inflating: /content/HAM10000/ISIC_0029992.jpg
#   inflating: /content/HAM10000/ISIC_0029993.jpg
#   inflating: /content/HAM10000/ISIC_0029994.jpg
#   inflating: /content/HAM10000/ISIC_0029995.jpg
#   inflating: /content/HAM10000/ISIC_0029996.jpg
#   inflating: /content/HAM10000/ISIC_0029997.jpg
#   inflating: /content/HAM10000/ISIC_0029998.jpg
#   inflating: /content/HAM10000/ISIC_0029999.jpg
#   inflating: /content/HAM10000/ISIC_0030000.jpg
#   inflating: /content/HAM10000/ISIC_0030001.jpg
#   inflating: /content/HAM10000/ISIC_0030002.jpg
#   inflating: /content/HAM10000/ISIC_0030003.jpg
#   inflating: /content/HAM10000/ISIC_0030004.jpg
#   inflating: /content/HAM10000/ISIC_0030005.jpg
#   inflating: /content/HAM10000/ISIC_0030006.jpg
#   inflating: /content/HAM10000/ISIC_0030007.jpg
#   inflating: /content/HAM10000/ISIC_0030008.jpg
#   inflating: /content/HAM10000/ISIC_0030009.jpg
#   inflating: /content/HAM10000/ISIC_0030010.jpg
#   inflating: /content/HAM10000/ISIC_0030011.jpg
#   inflating: /content/HAM10000/ISIC_0030012.jpg
#   inflating: /content/HAM10000/ISIC_0030013.jpg
#   inflating: /content/HAM10000/ISIC_0030014.jpg
#   inflating: /content/HAM10000/ISIC_0030015.jpg
#   inflating: /content/HAM10000/ISIC_0030016.jpg
#   inflating: /content/HAM10000/ISIC_0030017.jpg
#   inflating: /content/HAM10000/ISIC_0030018.jpg
#   inflating: /content/HAM10000/ISIC_0030019.jpg
#   inflating: /content/HAM10000/ISIC_0030020.jpg
#   inflating: /content/HAM10000/ISIC_0030021.jpg
#   inflating: /content/HAM10000/ISIC_0030022.jpg
#   inflating: /content/HAM10000/ISIC_0030023.jpg
#   inflating: /content/HAM10000/ISIC_0030024.jpg
#   inflating: /content/HAM10000/ISIC_0030025.jpg
#   inflating: /content/HAM10000/ISIC_0030026.jpg
#   inflating: /content/HAM10000/ISIC_0030027.jpg
#   inflating: /content/HAM10000/ISIC_0030028.jpg
#   inflating: /content/HAM10000/ISIC_0030029.jpg
#   inflating: /content/HAM10000/ISIC_0030030.jpg
#   inflating: /content/HAM10000/ISIC_0030031.jpg
#   inflating: /content/HAM10000/ISIC_0030032.jpg
#   inflating: /content/HAM10000/ISIC_0030033.jpg
#   inflating: /content/HAM10000/ISIC_0030034.jpg
#   inflating: /content/HAM10000/ISIC_0030035.jpg
#   inflating: /content/HAM10000/ISIC_0030036.jpg
#   inflating: /content/HAM10000/ISIC_0030037.jpg
#   inflating: /content/HAM10000/ISIC_0030038.jpg
#   inflating: /content/HAM10000/ISIC_0030039.jpg
#   inflating: /content/HAM10000/ISIC_0030040.jpg
#   inflating: /content/HAM10000/ISIC_0030041.jpg
#   inflating: /content/HAM10000/ISIC_0030042.jpg
#   inflating: /content/HAM10000/ISIC_0030043.jpg
#   inflating: /content/HAM10000/ISIC_0030044.jpg
#   inflating: /content/HAM10000/ISIC_0030045.jpg
#   inflating: /content/HAM10000/ISIC_0030046.jpg
#   inflating: /content/HAM10000/ISIC_0030047.jpg
#   inflating: /content/HAM10000/ISIC_0030048.jpg
#   inflating: /content/HAM10000/ISIC_0030049.jpg
#   inflating: /content/HAM10000/ISIC_0030050.jpg
#   inflating: /content/HAM10000/ISIC_0030051.jpg
#   inflating: /content/HAM10000/ISIC_0030052.jpg
#   inflating: /content/HAM10000/ISIC_0030053.jpg
#   inflating: /content/HAM10000/ISIC_0030054.jpg
#   inflating: /content/HAM10000/ISIC_0030055.jpg
#   inflating: /content/HAM10000/ISIC_0030056.jpg
#   inflating: /content/HAM10000/ISIC_0030057.jpg
#   inflating: /content/HAM10000/ISIC_0030058.jpg
#   inflating: /content/HAM10000/ISIC_0030059.jpg
#   inflating: /content/HAM10000/ISIC_0030060.jpg
#   inflating: /content/HAM10000/ISIC_0030061.jpg
#   inflating: /content/HAM10000/ISIC_0030062.jpg
#   inflating: /content/HAM10000/ISIC_0030063.jpg
#   inflating: /content/HAM10000/ISIC_0030064.jpg
#   inflating: /content/HAM10000/ISIC_0030065.jpg
#   inflating: /content/HAM10000/ISIC_0030066.jpg
#   inflating: /content/HAM10000/ISIC_0030067.jpg
#   inflating: /content/HAM10000/ISIC_0030068.jpg
#   inflating: /content/HAM10000/ISIC_0030069.jpg
#   inflating: /content/HAM10000/ISIC_0030070.jpg
#   inflating: /content/HAM10000/ISIC_0030071.jpg
#   inflating: /content/HAM10000/ISIC_0030072.jpg
#   inflating: /content/HAM10000/ISIC_0030073.jpg
#   inflating: /content/HAM10000/ISIC_0030074.jpg
#   inflating: /content/HAM10000/ISIC_0030075.jpg
#   inflating: /content/HAM10000/ISIC_0030076.jpg
#   inflating: /content/HAM10000/ISIC_0030077.jpg
#   inflating: /content/HAM10000/ISIC_0030078.jpg
#   inflating: /content/HAM10000/ISIC_0030079.jpg
#   inflating: /content/HAM10000/ISIC_0030080.jpg
#   inflating: /content/HAM10000/ISIC_0030081.jpg
#   inflating: /content/HAM10000/ISIC_0030082.jpg
#   inflating: /content/HAM10000/ISIC_0030083.jpg
#   inflating: /content/HAM10000/ISIC_0030084.jpg
#   inflating: /content/HAM10000/ISIC_0030085.jpg
#   inflating: /content/HAM10000/ISIC_0030086.jpg
#   inflating: /content/HAM10000/ISIC_0030087.jpg
#   inflating: /content/HAM10000/ISIC_0030088.jpg
#   inflating: /content/HAM10000/ISIC_0030089.jpg
#   inflating: /content/HAM10000/ISIC_0030090.jpg
#   inflating: /content/HAM10000/ISIC_0030091.jpg
#   inflating: /content/HAM10000/ISIC_0030092.jpg
#   inflating: /content/HAM10000/ISIC_0030093.jpg
#   inflating: /content/HAM10000/ISIC_0030094.jpg
#   inflating: /content/HAM10000/ISIC_0030095.jpg
#   inflating: /content/HAM10000/ISIC_0030096.jpg
#   inflating: /content/HAM10000/ISIC_0030097.jpg
#   inflating: /content/HAM10000/ISIC_0030098.jpg
#   inflating: /content/HAM10000/ISIC_0030099.jpg
#   inflating: /content/HAM10000/ISIC_0030100.jpg
#   inflating: /content/HAM10000/ISIC_0030101.jpg
#   inflating: /content/HAM10000/ISIC_0030102.jpg
#   inflating: /content/HAM10000/ISIC_0030103.jpg
#   inflating: /content/HAM10000/ISIC_0030104.jpg
#   inflating: /content/HAM10000/ISIC_0030105.jpg
#   inflating: /content/HAM10000/ISIC_0030106.jpg
#   inflating: /content/HAM10000/ISIC_0030107.jpg
#   inflating: /content/HAM10000/ISIC_0030108.jpg
#   inflating: /content/HAM10000/ISIC_0030109.jpg
#   inflating: /content/HAM10000/ISIC_0030110.jpg
#   inflating: /content/HAM10000/ISIC_0030111.jpg
#   inflating: /content/HAM10000/ISIC_0030112.jpg
#   inflating: /content/HAM10000/ISIC_0030113.jpg
#   inflating: /content/HAM10000/ISIC_0030114.jpg
#   inflating: /content/HAM10000/ISIC_0030115.jpg
#   inflating: /content/HAM10000/ISIC_0030116.jpg
#   inflating: /content/HAM10000/ISIC_0030117.jpg
#   inflating: /content/HAM10000/ISIC_0030118.jpg
#   inflating: /content/HAM10000/ISIC_0030119.jpg
#   inflating: /content/HAM10000/ISIC_0030120.jpg
#   inflating: /content/HAM10000/ISIC_0030121.jpg
#   inflating: /content/HAM10000/ISIC_0030122.jpg
#   inflating: /content/HAM10000/ISIC_0030123.jpg
#   inflating: /content/HAM10000/ISIC_0030124.jpg
#   inflating: /content/HAM10000/ISIC_0030125.jpg
#   inflating: /content/HAM10000/ISIC_0030126.jpg
#   inflating: /content/HAM10000/ISIC_0030127.jpg
#   inflating: /content/HAM10000/ISIC_0030128.jpg
#   inflating: /content/HAM10000/ISIC_0030129.jpg
#   inflating: /content/HAM10000/ISIC_0030130.jpg
#   inflating: /content/HAM10000/ISIC_0030131.jpg
#   inflating: /content/HAM10000/ISIC_0030132.jpg
#   inflating: /content/HAM10000/ISIC_0030133.jpg
#   inflating: /content/HAM10000/ISIC_0030134.jpg
#   inflating: /content/HAM10000/ISIC_0030135.jpg
#   inflating: /content/HAM10000/ISIC_0030136.jpg
#   inflating: /content/HAM10000/ISIC_0030137.jpg
#   inflating: /content/HAM10000/ISIC_0030138.jpg
#   inflating: /content/HAM10000/ISIC_0030139.jpg
#   inflating: /content/HAM10000/ISIC_0030140.jpg
#   inflating: /content/HAM10000/ISIC_0030141.jpg
#   inflating: /content/HAM10000/ISIC_0030142.jpg
#   inflating: /content/HAM10000/ISIC_0030143.jpg
#   inflating: /content/HAM10000/ISIC_0030144.jpg
#   inflating: /content/HAM10000/ISIC_0030145.jpg
#   inflating: /content/HAM10000/ISIC_0030146.jpg
#   inflating: /content/HAM10000/ISIC_0030147.jpg
#   inflating: /content/HAM10000/ISIC_0030148.jpg
#   inflating: /content/HAM10000/ISIC_0030149.jpg
#   inflating: /content/HAM10000/ISIC_0030150.jpg
#   inflating: /content/HAM10000/ISIC_0030151.jpg
#   inflating: /content/HAM10000/ISIC_0030152.jpg
#   inflating: /content/HAM10000/ISIC_0030153.jpg
#   inflating: /content/HAM10000/ISIC_0030154.jpg
#   inflating: /content/HAM10000/ISIC_0030155.jpg
#   inflating: /content/HAM10000/ISIC_0030156.jpg
#   inflating: /content/HAM10000/ISIC_0030157.jpg
#   inflating: /content/HAM10000/ISIC_0030158.jpg
#   inflating: /content/HAM10000/ISIC_0030159.jpg
#   inflating: /content/HAM10000/ISIC_0030160.jpg
#   inflating: /content/HAM10000/ISIC_0030161.jpg
#   inflating: /content/HAM10000/ISIC_0030162.jpg
#   inflating: /content/HAM10000/ISIC_0030163.jpg
#   inflating: /content/HAM10000/ISIC_0030164.jpg
#   inflating: /content/HAM10000/ISIC_0030165.jpg
#   inflating: /content/HAM10000/ISIC_0030166.jpg
#   inflating: /content/HAM10000/ISIC_0030167.jpg
#   inflating: /content/HAM10000/ISIC_0030168.jpg
#   inflating: /content/HAM10000/ISIC_0030169.jpg
#   inflating: /content/HAM10000/ISIC_0030170.jpg
#   inflating: /content/HAM10000/ISIC_0030171.jpg
#   inflating: /content/HAM10000/ISIC_0030172.jpg
#   inflating: /content/HAM10000/ISIC_0030173.jpg
#   inflating: /content/HAM10000/ISIC_0030174.jpg
#   inflating: /content/HAM10000/ISIC_0030175.jpg
#   inflating: /content/HAM10000/ISIC_0030176.jpg
#   inflating: /content/HAM10000/ISIC_0030177.jpg
#   inflating: /content/HAM10000/ISIC_0030178.jpg
#   inflating: /content/HAM10000/ISIC_0030179.jpg
#   inflating: /content/HAM10000/ISIC_0030180.jpg
#   inflating: /content/HAM10000/ISIC_0030181.jpg
#   inflating: /content/HAM10000/ISIC_0030182.jpg
#   inflating: /content/HAM10000/ISIC_0030183.jpg
#   inflating: /content/HAM10000/ISIC_0030184.jpg
#   inflating: /content/HAM10000/ISIC_0030185.jpg
#   inflating: /content/HAM10000/ISIC_0030186.jpg
#   inflating: /content/HAM10000/ISIC_0030187.jpg
#   inflating: /content/HAM10000/ISIC_0030188.jpg
#   inflating: /content/HAM10000/ISIC_0030189.jpg
#   inflating: /content/HAM10000/ISIC_0030190.jpg
#   inflating: /content/HAM10000/ISIC_0030191.jpg
#   inflating: /content/HAM10000/ISIC_0030192.jpg
#   inflating: /content/HAM10000/ISIC_0030193.jpg
#   inflating: /content/HAM10000/ISIC_0030194.jpg
#   inflating: /content/HAM10000/ISIC_0030195.jpg
#   inflating: /content/HAM10000/ISIC_0030196.jpg
#   inflating: /content/HAM10000/ISIC_0030197.jpg
#   inflating: /content/HAM10000/ISIC_0030198.jpg
#   inflating: /content/HAM10000/ISIC_0030199.jpg
#   inflating: /content/HAM10000/ISIC_0030200.jpg
#   inflating: /content/HAM10000/ISIC_0030201.jpg
#   inflating: /content/HAM10000/ISIC_0030202.jpg
#   inflating: /content/HAM10000/ISIC_0030203.jpg
#   inflating: /content/HAM10000/ISIC_0030204.jpg
#   inflating: /content/HAM10000/ISIC_0030205.jpg
#   inflating: /content/HAM10000/ISIC_0030206.jpg
#   inflating: /content/HAM10000/ISIC_0030207.jpg
#   inflating: /content/HAM10000/ISIC_0030208.jpg
#   inflating: /content/HAM10000/ISIC_0030209.jpg
#   inflating: /content/HAM10000/ISIC_0030210.jpg
#   inflating: /content/HAM10000/ISIC_0030211.jpg
#   inflating: /content/HAM10000/ISIC_0030212.jpg
#   inflating: /content/HAM10000/ISIC_0030213.jpg
#   inflating: /content/HAM10000/ISIC_0030214.jpg
#   inflating: /content/HAM10000/ISIC_0030215.jpg
#   inflating: /content/HAM10000/ISIC_0030216.jpg
#   inflating: /content/HAM10000/ISIC_0030217.jpg
#   inflating: /content/HAM10000/ISIC_0030218.jpg
#   inflating: /content/HAM10000/ISIC_0030219.jpg
#   inflating: /content/HAM10000/ISIC_0030220.jpg
#   inflating: /content/HAM10000/ISIC_0030221.jpg
#   inflating: /content/HAM10000/ISIC_0030222.jpg
#   inflating: /content/HAM10000/ISIC_0030223.jpg
#   inflating: /content/HAM10000/ISIC_0030224.jpg
#   inflating: /content/HAM10000/ISIC_0030225.jpg
#   inflating: /content/HAM10000/ISIC_0030226.jpg
#   inflating: /content/HAM10000/ISIC_0030227.jpg
#   inflating: /content/HAM10000/ISIC_0030228.jpg
#   inflating: /content/HAM10000/ISIC_0030229.jpg
#   inflating: /content/HAM10000/ISIC_0030230.jpg
#   inflating: /content/HAM10000/ISIC_0030231.jpg
#   inflating: /content/HAM10000/ISIC_0030232.jpg
#   inflating: /content/HAM10000/ISIC_0030233.jpg
#   inflating: /content/HAM10000/ISIC_0030234.jpg
#   inflating: /content/HAM10000/ISIC_0030235.jpg
#   inflating: /content/HAM10000/ISIC_0030236.jpg
#   inflating: /content/HAM10000/ISIC_0030237.jpg
#   inflating: /content/HAM10000/ISIC_0030238.jpg
#   inflating: /content/HAM10000/ISIC_0030239.jpg
#   inflating: /content/HAM10000/ISIC_0030240.jpg
#   inflating: /content/HAM10000/ISIC_0030241.jpg
#   inflating: /content/HAM10000/ISIC_0030242.jpg
#   inflating: /content/HAM10000/ISIC_0030243.jpg
#   inflating: /content/HAM10000/ISIC_0030244.jpg
#   inflating: /content/HAM10000/ISIC_0030245.jpg
#   inflating: /content/HAM10000/ISIC_0030246.jpg
#   inflating: /content/HAM10000/ISIC_0030247.jpg
#   inflating: /content/HAM10000/ISIC_0030248.jpg
#   inflating: /content/HAM10000/ISIC_0030249.jpg
#   inflating: /content/HAM10000/ISIC_0030250.jpg
#   inflating: /content/HAM10000/ISIC_0030251.jpg
#   inflating: /content/HAM10000/ISIC_0030252.jpg
#   inflating: /content/HAM10000/ISIC_0030253.jpg
#   inflating: /content/HAM10000/ISIC_0030254.jpg
#   inflating: /content/HAM10000/ISIC_0030255.jpg
#   inflating: /content/HAM10000/ISIC_0030256.jpg
#   inflating: /content/HAM10000/ISIC_0030257.jpg
#   inflating: /content/HAM10000/ISIC_0030258.jpg
#   inflating: /content/HAM10000/ISIC_0030259.jpg
#   inflating: /content/HAM10000/ISIC_0030260.jpg
#   inflating: /content/HAM10000/ISIC_0030261.jpg
#   inflating: /content/HAM10000/ISIC_0030262.jpg
#   inflating: /content/HAM10000/ISIC_0030263.jpg
#   inflating: /content/HAM10000/ISIC_0030264.jpg
#   inflating: /content/HAM10000/ISIC_0030265.jpg
#   inflating: /content/HAM10000/ISIC_0030266.jpg
#   inflating: /content/HAM10000/ISIC_0030267.jpg
#   inflating: /content/HAM10000/ISIC_0030268.jpg
#   inflating: /content/HAM10000/ISIC_0030269.jpg
#   inflating: /content/HAM10000/ISIC_0030270.jpg
#   inflating: /content/HAM10000/ISIC_0030271.jpg
#   inflating: /content/HAM10000/ISIC_0030272.jpg
#   inflating: /content/HAM10000/ISIC_0030273.jpg
#   inflating: /content/HAM10000/ISIC_0030274.jpg
#   inflating: /content/HAM10000/ISIC_0030275.jpg
#   inflating: /content/HAM10000/ISIC_0030276.jpg
#   inflating: /content/HAM10000/ISIC_0030277.jpg
#   inflating: /content/HAM10000/ISIC_0030278.jpg
# ...
#   inflating: /content/HAM10000/ISIC_0034001.jpg
#   inflating: /content/HAM10000/ISIC_0034002.jpg
#   inflating: /content/HAM10000/ISIC_0034003.jpg
#   inflating: /content/HAM10000/ISIC_0034004.jpg
#   inflating: /content/HAM10000/ISIC_0034005.jpg
#   inflating: /content/HAM10000/ISIC_0034006.jpg
#   inflating: /content/HAM10000/ISIC_0034007.jpg
#   inflating: /content/HAM10000/ISIC_0034008.jpg
#   inflating: /content/HAM10000/ISIC_0034009.jpg
#   inflating: /content/HAM10000/ISIC_0034010.jpg
#   inflating: /content/HAM10000/ISIC_0034011.jpg
#   inflating: /content/HAM10000/ISIC_0034012.jpg
#   inflating: /content/HAM10000/ISIC_0034013.jpg
#   inflating: /content/HAM10000/ISIC_0034014.jpg
#   inflating: /content/HAM10000/ISIC_0034015.jpg
#   inflating: /content/HAM10000/ISIC_0034016.jpg
#   inflating: /content/HAM10000/ISIC_0034017.jpg
#   inflating: /content/HAM10000/ISIC_0034018.jpg
#   inflating: /content/HAM10000/ISIC_0034019.jpg
#   inflating: /content/HAM10000/ISIC_0034020.jpg
#   inflating: /content/HAM10000/ISIC_0034021.jpg
#   inflating: /content/HAM10000/ISIC_0034022.jpg
#   inflating: /content/HAM10000/ISIC_0034023.jpg
#   inflating: /content/HAM10000/ISIC_0034024.jpg
#   inflating: /content/HAM10000/ISIC_0034025.jpg
#   inflating: /content/HAM10000/ISIC_0034026.jpg
#   inflating: /content/HAM10000/ISIC_0034027.jpg
#   inflating: /content/HAM10000/ISIC_0034028.jpg
#   inflating: /content/HAM10000/ISIC_0034029.jpg
#   inflating: /content/HAM10000/ISIC_0034030.jpg
#   inflating: /content/HAM10000/ISIC_0034031.jpg
#   inflating: /content/HAM10000/ISIC_0034032.jpg
#   inflating: /content/HAM10000/ISIC_0034033.jpg
#   inflating: /content/HAM10000/ISIC_0034034.jpg
#   inflating: /content/HAM10000/ISIC_0034035.jpg
#   inflating: /content/HAM10000/ISIC_0034036.jpg
#   inflating: /content/HAM10000/ISIC_0034037.jpg
#   inflating: /content/HAM10000/ISIC_0034038.jpg
#   inflating: /content/HAM10000/ISIC_0034039.jpg
#   inflating: /content/HAM10000/ISIC_0034040.jpg
#   inflating: /content/HAM10000/ISIC_0034041.jpg
#   inflating: /content/HAM10000/ISIC_0034042.jpg
#   inflating: /content/HAM10000/ISIC_0034043.jpg
#   inflating: /content/HAM10000/ISIC_0034044.jpg
#   inflating: /content/HAM10000/ISIC_0034045.jpg
#   inflating: /content/HAM10000/ISIC_0034046.jpg
#   inflating: /content/HAM10000/ISIC_0034047.jpg
#   inflating: /content/HAM10000/ISIC_0034048.jpg
#   inflating: /content/HAM10000/ISIC_0034049.jpg
#   inflating: /content/HAM10000/ISIC_0034050.jpg
#   inflating: /content/HAM10000/ISIC_0034051.jpg
#   inflating: /content/HAM10000/ISIC_0034052.jpg
#   inflating: /content/HAM10000/ISIC_0034053.jpg
#   inflating: /content/HAM10000/ISIC_0034054.jpg
#   inflating: /content/HAM10000/ISIC_0034055.jpg
#   inflating: /content/HAM10000/ISIC_0034056.jpg
#   inflating: /content/HAM10000/ISIC_0034057.jpg
#   inflating: /content/HAM10000/ISIC_0034058.jpg
#   inflating: /content/HAM10000/ISIC_0034059.jpg
#   inflating: /content/HAM10000/ISIC_0034060.jpg
#   inflating: /content/HAM10000/ISIC_0034061.jpg
#   inflating: /content/HAM10000/ISIC_0034062.jpg
#   inflating: /content/HAM10000/ISIC_0034063.jpg
#   inflating: /content/HAM10000/ISIC_0034064.jpg
#   inflating: /content/HAM10000/ISIC_0034065.jpg
#   inflating: /content/HAM10000/ISIC_0034066.jpg
#   inflating: /content/HAM10000/ISIC_0034067.jpg
#   inflating: /content/HAM10000/ISIC_0034068.jpg
#   inflating: /content/HAM10000/ISIC_0034069.jpg
#   inflating: /content/HAM10000/ISIC_0034070.jpg
#   inflating: /content/HAM10000/ISIC_0034071.jpg
#   inflating: /content/HAM10000/ISIC_0034072.jpg
#   inflating: /content/HAM10000/ISIC_0034073.jpg
#   inflating: /content/HAM10000/ISIC_0034074.jpg
#   inflating: /content/HAM10000/ISIC_0034075.jpg
#   inflating: /content/HAM10000/ISIC_0034076.jpg
#   inflating: /content/HAM10000/ISIC_0034077.jpg
#   inflating: /content/HAM10000/ISIC_0034078.jpg
#   inflating: /content/HAM10000/ISIC_0034079.jpg
#   inflating: /content/HAM10000/ISIC_0034080.jpg
#   inflating: /content/HAM10000/ISIC_0034081.jpg
#   inflating: /content/HAM10000/ISIC_0034082.jpg
#   inflating: /content/HAM10000/ISIC_0034083.jpg
#   inflating: /content/HAM10000/ISIC_0034084.jpg
#   inflating: /content/HAM10000/ISIC_0034085.jpg
#   inflating: /content/HAM10000/ISIC_0034086.jpg
#   inflating: /content/HAM10000/ISIC_0034087.jpg
#   inflating: /content/HAM10000/ISIC_0034088.jpg
#   inflating: /content/HAM10000/ISIC_0034089.jpg
#   inflating: /content/HAM10000/ISIC_0034090.jpg
#   inflating: /content/HAM10000/ISIC_0034091.jpg
#   inflating: /content/HAM10000/ISIC_0034092.jpg
#   inflating: /content/HAM10000/ISIC_0034093.jpg
#   inflating: /content/HAM10000/ISIC_0034094.jpg
#   inflating: /content/HAM10000/ISIC_0034095.jpg
#   inflating: /content/HAM10000/ISIC_0034096.jpg
#   inflating: /content/HAM10000/ISIC_0034097.jpg
#   inflating: /content/HAM10000/ISIC_0034098.jpg
#   inflating: /content/HAM10000/ISIC_0034099.jpg
#   inflating: /content/HAM10000/ISIC_0034100.jpg
#   inflating: /content/HAM10000/ISIC_0034101.jpg
#   inflating: /content/HAM10000/ISIC_0034102.jpg
#   inflating: /content/HAM10000/ISIC_0034103.jpg
#   inflating: /content/HAM10000/ISIC_0034104.jpg
#   inflating: /content/HAM10000/ISIC_0034105.jpg
#   inflating: /content/HAM10000/ISIC_0034106.jpg
#   inflating: /content/HAM10000/ISIC_0034107.jpg
#   inflating: /content/HAM10000/ISIC_0034108.jpg
#   inflating: /content/HAM10000/ISIC_0034109.jpg
#   inflating: /content/HAM10000/ISIC_0034110.jpg
#   inflating: /content/HAM10000/ISIC_0034111.jpg
#   inflating: /content/HAM10000/ISIC_0034112.jpg
#   inflating: /content/HAM10000/ISIC_0034113.jpg
#   inflating: /content/HAM10000/ISIC_0034114.jpg
#   inflating: /content/HAM10000/ISIC_0034115.jpg
#   inflating: /content/HAM10000/ISIC_0034116.jpg
#   inflating: /content/HAM10000/ISIC_0034117.jpg
#   inflating: /content/HAM10000/ISIC_0034118.jpg
#   inflating: /content/HAM10000/ISIC_0034119.jpg
#   inflating: /content/HAM10000/ISIC_0034120.jpg
#   inflating: /content/HAM10000/ISIC_0034121.jpg
#   inflating: /content/HAM10000/ISIC_0034122.jpg
#   inflating: /content/HAM10000/ISIC_0034123.jpg
#   inflating: /content/HAM10000/ISIC_0034124.jpg
#   inflating: /content/HAM10000/ISIC_0034125.jpg
#   inflating: /content/HAM10000/ISIC_0034126.jpg
#   inflating: /content/HAM10000/ISIC_0034127.jpg
#   inflating: /content/HAM10000/ISIC_0034128.jpg
#   inflating: /content/HAM10000/ISIC_0034129.jpg
#   inflating: /content/HAM10000/ISIC_0034130.jpg
#   inflating: /content/HAM10000/ISIC_0034131.jpg
#   inflating: /content/HAM10000/ISIC_0034132.jpg
#   inflating: /content/HAM10000/ISIC_0034133.jpg
#   inflating: /content/HAM10000/ISIC_0034134.jpg
#   inflating: /content/HAM10000/ISIC_0034135.jpg
#   inflating: /content/HAM10000/ISIC_0034136.jpg
#   inflating: /content/HAM10000/ISIC_0034137.jpg
#   inflating: /content/HAM10000/ISIC_0034138.jpg
#   inflating: /content/HAM10000/ISIC_0034139.jpg
#   inflating: /content/HAM10000/ISIC_0034140.jpg
#   inflating: /content/HAM10000/ISIC_0034141.jpg
#   inflating: /content/HAM10000/ISIC_0034142.jpg
#   inflating: /content/HAM10000/ISIC_0034143.jpg
#   inflating: /content/HAM10000/ISIC_0034144.jpg
#   inflating: /content/HAM10000/ISIC_0034145.jpg
#   inflating: /content/HAM10000/ISIC_0034146.jpg
#   inflating: /content/HAM10000/ISIC_0034147.jpg
#   inflating: /content/HAM10000/ISIC_0034148.jpg
#   inflating: /content/HAM10000/ISIC_0034149.jpg
#   inflating: /content/HAM10000/ISIC_0034150.jpg
#   inflating: /content/HAM10000/ISIC_0034151.jpg
#   inflating: /content/HAM10000/ISIC_0034152.jpg
#   inflating: /content/HAM10000/ISIC_0034153.jpg
#   inflating: /content/HAM10000/ISIC_0034154.jpg
#   inflating: /content/HAM10000/ISIC_0034155.jpg
#   inflating: /content/HAM10000/ISIC_0034156.jpg
#   inflating: /content/HAM10000/ISIC_0034157.jpg
#   inflating: /content/HAM10000/ISIC_0034158.jpg
#   inflating: /content/HAM10000/ISIC_0034159.jpg
#   inflating: /content/HAM10000/ISIC_0034160.jpg
#   inflating: /content/HAM10000/ISIC_0034161.jpg
#   inflating: /content/HAM10000/ISIC_0034162.jpg
#   inflating: /content/HAM10000/ISIC_0034163.jpg
#   inflating: /content/HAM10000/ISIC_0034164.jpg
#   inflating: /content/HAM10000/ISIC_0034165.jpg
#   inflating: /content/HAM10000/ISIC_0034166.jpg
#   inflating: /content/HAM10000/ISIC_0034167.jpg
#   inflating: /content/HAM10000/ISIC_0034168.jpg
#   inflating: /content/HAM10000/ISIC_0034169.jpg
#   inflating: /content/HAM10000/ISIC_0034170.jpg
#   inflating: /content/HAM10000/ISIC_0034171.jpg
#   inflating: /content/HAM10000/ISIC_0034172.jpg
#   inflating: /content/HAM10000/ISIC_0034173.jpg
#   inflating: /content/HAM10000/ISIC_0034174.jpg
#   inflating: /content/HAM10000/ISIC_0034175.jpg
#   inflating: /content/HAM10000/ISIC_0034176.jpg
#   inflating: /content/HAM10000/ISIC_0034177.jpg
#   inflating: /content/HAM10000/ISIC_0034178.jpg
#   inflating: /content/HAM10000/ISIC_0034179.jpg
#   inflating: /content/HAM10000/ISIC_0034180.jpg
#   inflating: /content/HAM10000/ISIC_0034181.jpg
#   inflating: /content/HAM10000/ISIC_0034182.jpg
#   inflating: /content/HAM10000/ISIC_0034183.jpg
#   inflating: /content/HAM10000/ISIC_0034184.jpg
#   inflating: /content/HAM10000/ISIC_0034185.jpg
#   inflating: /content/HAM10000/ISIC_0034186.jpg
#   inflating: /content/HAM10000/ISIC_0034187.jpg
#   inflating: /content/HAM10000/ISIC_0034188.jpg
#   inflating: /content/HAM10000/ISIC_0034189.jpg
#   inflating: /content/HAM10000/ISIC_0034190.jpg
#   inflating: /content/HAM10000/ISIC_0034191.jpg
#   inflating: /content/HAM10000/ISIC_0034192.jpg
#   inflating: /content/HAM10000/ISIC_0034193.jpg
#   inflating: /content/HAM10000/ISIC_0034194.jpg
#   inflating: /content/HAM10000/ISIC_0034195.jpg
#   inflating: /content/HAM10000/ISIC_0034196.jpg
#   inflating: /content/HAM10000/ISIC_0034197.jpg
#   inflating: /content/HAM10000/ISIC_0034198.jpg
#   inflating: /content/HAM10000/ISIC_0034199.jpg
#   inflating: /content/HAM10000/ISIC_0034200.jpg
#   inflating: /content/HAM10000/ISIC_0034201.jpg
#   inflating: /content/HAM10000/ISIC_0034202.jpg
#   inflating: /content/HAM10000/ISIC_0034203.jpg
#   inflating: /content/HAM10000/ISIC_0034204.jpg
#   inflating: /content/HAM10000/ISIC_0034205.jpg
#   inflating: /content/HAM10000/ISIC_0034206.jpg
#   inflating: /content/HAM10000/ISIC_0034207.jpg
#   inflating: /content/HAM10000/ISIC_0034208.jpg
#   inflating: /content/HAM10000/ISIC_0034209.jpg
#   inflating: /content/HAM10000/ISIC_0034210.jpg
#   inflating: /content/HAM10000/ISIC_0034211.jpg
#   inflating: /content/HAM10000/ISIC_0034212.jpg
#   inflating: /content/HAM10000/ISIC_0034213.jpg
#   inflating: /content/HAM10000/ISIC_0034214.jpg
#   inflating: /content/HAM10000/ISIC_0034215.jpg
#   inflating: /content/HAM10000/ISIC_0034216.jpg
#   inflating: /content/HAM10000/ISIC_0034217.jpg
#   inflating: /content/HAM10000/ISIC_0034218.jpg
#   inflating: /content/HAM10000/ISIC_0034219.jpg
#   inflating: /content/HAM10000/ISIC_0034220.jpg
#   inflating: /content/HAM10000/ISIC_0034221.jpg
#   inflating: /content/HAM10000/ISIC_0034222.jpg
#   inflating: /content/HAM10000/ISIC_0034223.jpg
#   inflating: /content/HAM10000/ISIC_0034224.jpg
#   inflating: /content/HAM10000/ISIC_0034225.jpg
#   inflating: /content/HAM10000/ISIC_0034226.jpg
#   inflating: /content/HAM10000/ISIC_0034227.jpg
#   inflating: /content/HAM10000/ISIC_0034228.jpg
#   inflating: /content/HAM10000/ISIC_0034229.jpg
#   inflating: /content/HAM10000/ISIC_0034230.jpg
#   inflating: /content/HAM10000/ISIC_0034231.jpg
#   inflating: /content/HAM10000/ISIC_0034232.jpg
#   inflating: /content/HAM10000/ISIC_0034233.jpg
#   inflating: /content/HAM10000/ISIC_0034234.jpg
#   inflating: /content/HAM10000/ISIC_0034235.jpg
#   inflating: /content/HAM10000/ISIC_0034236.jpg
#   inflating: /content/HAM10000/ISIC_0034237.jpg
#   inflating: /content/HAM10000/ISIC_0034238.jpg
#   inflating: /content/HAM10000/ISIC_0034239.jpg
#   inflating: /content/HAM10000/ISIC_0034240.jpg
#   inflating: /content/HAM10000/ISIC_0034241.jpg
#   inflating: /content/HAM10000/ISIC_0034242.jpg
#   inflating: /content/HAM10000/ISIC_0034243.jpg
#   inflating: /content/HAM10000/ISIC_0034244.jpg
#   inflating: /content/HAM10000/ISIC_0034245.jpg
#   inflating: /content/HAM10000/ISIC_0034246.jpg
#   inflating: /content/HAM10000/ISIC_0034247.jpg
#   inflating: /content/HAM10000/ISIC_0034248.jpg
#   inflating: /content/HAM10000/ISIC_0034249.jpg
#   inflating: /content/HAM10000/ISIC_0034250.jpg
#   inflating: /content/HAM10000/ISIC_0034251.jpg
#   inflating: /content/HAM10000/ISIC_0034252.jpg
#   inflating: /content/HAM10000/ISIC_0034253.jpg
#   inflating: /content/HAM10000/ISIC_0034254.jpg
#   inflating: /content/HAM10000/ISIC_0034255.jpg
#   inflating: /content/HAM10000/ISIC_0034256.jpg
#   inflating: /content/HAM10000/ISIC_0034257.jpg
#   inflating: /content/HAM10000/ISIC_0034258.jpg
#   inflating: /content/HAM10000/ISIC_0034259.jpg
#   inflating: /content/HAM10000/ISIC_0034260.jpg
#   inflating: /content/HAM10000/ISIC_0034261.jpg
#   inflating: /content/HAM10000/ISIC_0034262.jpg
#   inflating: /content/HAM10000/ISIC_0034263.jpg
#   inflating: /content/HAM10000/ISIC_0034264.jpg
#   inflating: /content/HAM10000/ISIC_0034265.jpg
#   inflating: /content/HAM10000/ISIC_0034266.jpg
#   inflating: /content/HAM10000/ISIC_0034267.jpg
#   inflating: /content/HAM10000/ISIC_0034268.jpg
#   inflating: /content/HAM10000/ISIC_0034269.jpg
#   inflating: /content/HAM10000/ISIC_0034270.jpg
#   inflating: /content/HAM10000/ISIC_0034271.jpg
#   inflating: /content/HAM10000/ISIC_0034272.jpg
#   inflating: /content/HAM10000/ISIC_0034273.jpg
#   inflating: /content/HAM10000/ISIC_0034274.jpg
#   inflating: /content/HAM10000/ISIC_0034275.jpg
#   inflating: /content/HAM10000/ISIC_0034276.jpg
#   inflating: /content/HAM10000/ISIC_0034277.jpg
#   inflating: /content/HAM10000/ISIC_0034278.jpg
#   inflating: /content/HAM10000/ISIC_0034279.jpg
#   inflating: /content/HAM10000/ISIC_0034280.jpg
#   inflating: /content/HAM10000/ISIC_0034281.jpg
#   inflating: /content/HAM10000/ISIC_0034282.jpg
#   inflating: /content/HAM10000/ISIC_0034283.jpg
#   inflating: /content/HAM10000/ISIC_0034284.jpg
#   inflating: /content/HAM10000/ISIC_0034285.jpg
#   inflating: /content/HAM10000/ISIC_0034286.jpg
#   inflating: /content/HAM10000/ISIC_0034287.jpg
#   inflating: /content/HAM10000/ISIC_0034288.jpg
#   inflating: /content/HAM10000/ISIC_0034289.jpg
#   inflating: /content/HAM10000/ISIC_0034290.jpg
#   inflating: /content/HAM10000/ISIC_0034291.jpg
#   inflating: /content/HAM10000/ISIC_0034292.jpg
#   inflating: /content/HAM10000/ISIC_0034293.jpg
#   inflating: /content/HAM10000/ISIC_0034294.jpg
#   inflating: /content/HAM10000/ISIC_0034295.jpg
#   inflating: /content/HAM10000/ISIC_0034296.jpg
#   inflating: /content/HAM10000/ISIC_0034297.jpg
#   inflating: /content/HAM10000/ISIC_0034298.jpg
#   inflating: /content/HAM10000/ISIC_0034299.jpg
#   inflating: /content/HAM10000/ISIC_0034300.jpg
#   inflating: /content/HAM10000/ISIC_0034301.jpg
#   inflating: /content/HAM10000/ISIC_0034302.jpg
#   inflating: /content/HAM10000/ISIC_0034303.jpg
#   inflating: /content/HAM10000/ISIC_0034304.jpg
#   inflating: /content/HAM10000/ISIC_0034305.jpg
#   inflating: /content/HAM10000/ISIC_0034306.jpg
#   inflating: /content/HAM10000/ISIC_0034307.jpg
#   inflating: /content/HAM10000/ISIC_0034308.jpg
#   inflating: /content/HAM10000/ISIC_0034309.jpg
#   inflating: /content/HAM10000/ISIC_0034310.jpg
#   inflating: /content/HAM10000/ISIC_0034311.jpg
#   inflating: /content/HAM10000/ISIC_0034312.jpg
#   inflating: /content/HAM10000/ISIC_0034313.jpg
#   inflating: /content/HAM10000/ISIC_0034314.jpg
#   inflating: /content/HAM10000/ISIC_0034315.jpg
#   inflating: /content/HAM10000/ISIC_0034316.jpg
#   inflating: /content/HAM10000/ISIC_0034317.jpg
#   inflating: /content/HAM10000/ISIC_0034318.jpg
#   inflating: /content/HAM10000/ISIC_0034319.jpg
#   inflating: /content/HAM10000/ISIC_0034320.jpg

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
from glob import glob
from sklearn.metrics import roc_curve, auc
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score
from tensorflow.keras import callbacks 
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from  matplotlib import pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,GlobalAveragePooling2D,BatchNormalization,Dropout
# %matplotlib inline
import shutil
from sklearn.metrics import  precision_score, recall_score, accuracy_score,classification_report ,confusion_matrix
from tensorflow.python.platform import build_info as tf_build_info
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"
# os.environ["TF_CPP_VMODULE"]="gpu_process_state=10,gpu_cudamallocasync_allocator=10"
# a = tf.zeros([], tf.float32)

# %%
data = pd.read_csv('data/HAM10000_metadata')
data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern

# %%
unwanted_label = ['vasc','df']
data_pd = data.query("dx!=@unwanted_label")
print(data_pd['dx'].unique().tolist())
# Out:
# ['bkl', 'nv', 'mel', 'bcc', 'akiec']

# %%
train_dir = os.path.join('HAM10000', 'train_dir')
test_dir = os.path.join('HAM10000', 'test_dir')

# %%
df_count = data_pd.groupby('lesion_id').count()
df_count.head()
# Out:
#              image_id  dx  dx_type  age  sex  localization  dataset
# lesion_id
# HAM_0000000         2   2        2    2    2             2        2
# HAM_0000001         1   1        1    1    1             1        1
# HAM_0000002         3   3        3    3    3             3        3
# HAM_0000003         1   1        1    1    1             1        1
# HAM_0000004         1   1        1    1    1             1        1

# %%
df_count = df_count[df_count['dx'] == 1]
df_count.reset_index(inplace=True)

# %%
def duplicates(x):
    unique = set(df_count['lesion_id'])
    if x in unique:
        return 'no' 
    else:
        return 'duplicates'

# %%
data_pd['is_duplicate'] = data_pd['lesion_id'].apply(duplicates)
data_pd.head()
# Out:
# d:\pythonproject\hamclassification\venv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset is_duplicate
# 0  vidir_modern   duplicates
# 1  vidir_modern   duplicates
# 2  vidir_modern   duplicates
# 3  vidir_modern   duplicates
# 4  vidir_modern   duplicates

# %%
df_count = data_pd[data_pd['is_duplicate'] == 'no']

# %%
train, test_df = train_test_split(df_count, test_size=0.15, stratify=df_count['dx'])

# %%
def identify_trainOrtest(x):
    test_data = set(test_df['image_id'])
    if str(x) in test_data:
        return 'test'
    else:
        return 'train'

#creating train_df
data_pd['train_test_split'] = data_pd['image_id'].apply(identify_trainOrtest)
train_df = data_pd[data_pd['train_test_split'] == 'train']
train_df.head()
# Out:
# d:\pythonproject\hamclassification\venv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset is_duplicate train_test_split
# 0  vidir_modern   duplicates            train
# 1  vidir_modern   duplicates            train
# 2  vidir_modern   duplicates            train
# 3  vidir_modern   duplicates            train
# 4  vidir_modern   duplicates            train

# %%
test_df.head()
# Out:
#         lesion_id      image_id   dx    dx_type   age   sex localization  \
# 615   HAM_0005952  ISIC_0027916  bkl      histo  80.0  male         back
# 4636  HAM_0007389  ISIC_0029090   nv  follow_up  45.0  male        trunk
# 4276  HAM_0004894  ISIC_0030643   nv  follow_up  50.0  male        trunk
# 6033  HAM_0004610  ISIC_0025042   nv  follow_up  45.0  male        trunk
# 752   HAM_0004463  ISIC_0027770  bkl      histo  75.0  male         face
#
#             dataset is_duplicate
# 615       rosendahl           no
# 4636  vidir_molemax           no
# 4276  vidir_molemax           no
# 6033  vidir_molemax           no
# 752       rosendahl           no

# %%
# Image id of train and test images
train_list = list(train_df['image_id'])
test_list = list(test_df['image_id'])

# %%
len(test_list)
# Out:
# 812

# %%
len(train_list)
# Out:
# 8946

# %%
# Set the image_id as the index in data_pd
data_pd.set_index('image_id', inplace=True)

# %%
os.mkdir(train_dir)
os.mkdir(test_dir)

# %%
targetnames = ['akiec', 'bcc', 'bkl', 'mel', 'nv']

# %%
for i in targetnames:
  directory1=train_dir+'/'+i
  directory2=test_dir+'/'+i
  os.mkdir(directory1)
  os.mkdir(directory2)

# %%
for image in train_list:
    file_name = image+'.jpg'
    label = data_pd.loc[image, 'dx']

    # path of source image 
    source = os.path.join('HAM10000', file_name)

    # copying the image from the source to target file
    target = os.path.join(train_dir, label, file_name)

    shutil.copyfile(source, target)

# %%
for image in test_list:

    file_name = image+'.jpg'
    label = data_pd.loc[image, 'dx']

    # path of source image 
    source = os.path.join('HAM10000', file_name)

    # copying the image from the source to target file
    target = os.path.join(test_dir, label, file_name)

    shutil.copyfile(source, target)

# %%
targetnames = ['akiec', 'bcc', 'bkl', 'mel', 'nv']

# Augmenting images and storing them in temporary directories 
for img_class in targetnames:

    #creating temporary directories
    # creating a base directory
    aug_dir = 'aug_dir'
    os.mkdir(aug_dir)
    # creating a subdirectory inside the base directory for images of the same class
    img_dir = os.path.join(aug_dir, 'img_dir')
    os.mkdir(img_dir)

    img_list = os.listdir('HAM10000/train_dir/' + img_class)

    # Copy images from the class train dir to the img_dir 
    for file_name in img_list:

        # path of source image in training directory
        source = os.path.join('HAM10000/train_dir/' + img_class, file_name)

        # creating a target directory to send images 
        target = os.path.join(img_dir, file_name)

        # copying the image from the source to target file
        shutil.copyfile(source, target)

    # Temporary augumented dataset directory.
    source_path = aug_dir

    # Augmented images will be saved to training directory
    save_path = 'HAM10000/train_dir/' + img_class

    # Creating Image Data Generator to augment images
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(

        rotation_range=180,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest'

    )

    batch_size = 50

    aug_datagen = datagen.flow_from_directory(source_path,save_to_dir=save_path,save_format='jpg',target_size=(224, 224),batch_size=batch_size)

    # Generate the augmented images
    aug_images = 8000 

    num_files = len(os.listdir(img_dir))
    num_batches = int(np.ceil((aug_images - num_files) / batch_size))

    # creating 8000 augmented images per class
    for i in range(0, num_batches):
        images, labels = next(aug_datagen)

    # delete temporary directory 
    shutil.rmtree('aug_dir')
# Out:
# Found 304 images belonging to 1 classes.
# Found 488 images belonging to 1 classes.
# Found 1033 images belonging to 1 classes.
# Found 1079 images belonging to 1 classes.
# Found 6042 images belonging to 1 classes.

# %%
train_path = 'HAM10000/train_dir'
test_path = 'HAM10000/test_dir'
batch_size=16

# %%
datagen=ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)

# %%
image_size = 224
print("\nTrain Batches: ")
train_batches = datagen.flow_from_directory(directory=train_path,
                                            target_size=(image_size,image_size),
                                            batch_size=batch_size,
                                            shuffle=True)

print("\nTest Batches: ")
test_batches =datagen.flow_from_directory(test_path,
                                           target_size=(image_size,image_size),
                                           batch_size=batch_size,
                                           shuffle=False)
# Out:
# Train Batches:
# Found 38726 images belonging to 5 classes.
#
# Test Batches:
# Found 812 images belonging to 5 classes.

# %%
resnet = tf.keras.applications.ResNet50(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
)

output = resnet.output
output = Dense(5, activation='softmax', name='SoftMax')(output)
model = Model(inputs=resnet.input, outputs=output)

# %%
# output = GlobalAveragePooling2D()(conv)
# output = Dense(7, activation='softmax')(output)
# model = Model(inputs=resnet.input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         2049000     avg_pool[0][0]
# __________________________________________________________________________________________________
# SoftMax (Dense)                 (None, 5)            5005        predictions[0][0]
# ==================================================================================================
# Total params: 25,641,717
# Trainable params: 25,588,597
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
opt1=tf.keras.optimizers.Adam(learning_rate=0.01,epsilon=0.1)
model.compile(optimizer=opt1,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
class_weights = {   
                    0: 1.0,  # bkl
                    1: 1.0,  # nv
                    2: 5.0,  # mel
                    3: 1.0,  # bcc
                    4: 1.0,  # akiec
                }
                #['bkl', 'nv', 'mel', 'bcc', 'akiec']


checkpoint=  ModelCheckpoint(filepath = 'ResNet152.hdf5',monitor='val_accuracy',save_best_only=True,save_weights_only=True)
Earlystop = EarlyStopping(monitor='val_loss', mode='min',patience=40, min_delta=0.001)

# %%
# from numba import cuda
# device = cuda.get_current_device()
# print(device)
# device.reset()
# Out:
# <CUDA device 0 'b'GeForce GTX 1650 Ti''>

# %%
history = model.fit(train_batches,
                    steps_per_epoch=(len(train_df)/10),
                    epochs=300,
                    verbose=1,
                    validation_data=test_batches,validation_steps=len(test_df)/batch_size,callbacks=[checkpoint,Earlystop],class_weight=class_weights)
# Out:
# Epoch 1/300
# 894/894 [==============================] - 275s 296ms/step - loss: 2.3214 - accuracy: 0.2110 - val_loss: 1.2410 - val_accuracy: 0.0813
# Epoch 2/300
# 450/894 [==============>...............] - ETA: 2:05 - loss: 2.2222 - accuracy: 0.2071
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16952/2114876977.py in <module>
#       3                     epochs=300,
#       4                     verbose=1,
# ----> 5                     validation_data=test_batches,validation_steps=len(test_df)/batch_size,callbacks=[checkpoint,Earlystop],class_weight=class_weights)
#       6
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# d:\pythonproject\hamclassification\venv\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras import models
model.load_weights("ResNet152.hdf5")

# %%
predictions = model.predict(test_batches, steps=len(test_df)/batch_size, verbose=0)

# %%
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'mel', 'nv']
#getting the true labels per image 
y_true = test_batches.classes
#getting the predicted labels per image 
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report 
report = classification_report(y_true, y_pred, target_names=targetnames)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.74      0.74      0.74        23
#          bcc       0.91      0.77      0.83        26
#          bkl       0.67      0.50      0.57        66
#           df       0.80      0.67      0.73         6
#          mel       0.52      0.50      0.51        34
#           nv       0.95      0.98      0.96       663
#         vasc       0.90      0.90      0.90        10
#
#     accuracy                           0.90       828
#    macro avg       0.78      0.72      0.75       828
# weighted avg       0.90      0.90      0.90       828

# %%
print("Precision: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("weighted Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='weighted')))
# Out:
# Precision: 0.8981171733390011
# Recall: 0.9045893719806763
# Accuracy: 0.9045893719806763
# weighted Roc score: 0.9727752250647581

# %%
print("Precision: "+ str(precision_score(y_true, y_pred, average='macro')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='macro')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("Macro Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='macro')))
# Out:
# Precision: 0.7832723409602609
# Recall: 0.7219873902738353
# Accuracy: 0.9045893719806763
# Macro Roc score: 0.9758549231296252

# %%
print("Precision: "+ str(precision_score(y_true, y_pred, average='micro')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='micro')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
tpr={}
fpr={}
roc_auc={}
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
print("Micro Roc score: " + str(roc_auc["micro"]))
# Out:
# Precision: 0.9045893719806763
# Recall: 0.9045893719806763
# Accuracy: 0.9045893719806763
# Micro Roc score: 0.9931541333131073

# %%
fpr = {}
tpr = {}
roc_auc = {}
for i in range(7):
    r = roc_auc_score(y_test[:, i], y_prob[:, i])
    print("The ROC AUC score of "+targetnames[i]+" is: "+str(r))
# Out:
# The ROC AUC score of akiec is: 0.9808263570078315
# The ROC AUC score of bcc is: 0.9974582773834644
# The ROC AUC score of bkl is: 0.94887854927225
# The ROC AUC score of df is: 0.97323600973236
# The ROC AUC score of mel is: 0.9610683064157653
# The ROC AUC score of nv is: 0.9741624388683212
# The ROC AUC score of vasc is: 0.9953545232273838

# %%
# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_prob[:, i], drop_intermediate=False)
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
plt.plot(fpr[0], tpr[0],'v-',label='akiec: ROC curve of (area = %0.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1],'c',label='bcc: ROC curve of (area = %0.2f)' % roc_auc[1])
plt.plot(fpr[2], tpr[2],'b',label='bkl: ROC curve of (area = %0.2f)' % roc_auc[2])
plt.plot(fpr[3], tpr[3],'g',label='df: ROC curve of (area = %0.2f)' % roc_auc[3])
plt.plot(fpr[4], tpr[4],'y',label='mel: ROC curve of (area = %0.2f)' % roc_auc[4])
plt.plot(fpr[5], tpr[5],'o-',label='nv: ROC curve of (area = %0.2f)' % roc_auc[5])
plt.plot(fpr[6], tpr[6],'r',label='vasc: ROC curve of (area = %0.2f)' % roc_auc[6])

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of %s'%targetnames[i])
plt.legend(loc="lower right")
plt.show()
